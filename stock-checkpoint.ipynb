# %%
from FinMind.Data import Load
import numpy as np 
#import pandas as pd
import math
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import keras
from keras.layers.core import Dense, Dropout
from keras.layers import LSTM , GRU, normalization
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import math
from keras.optimizers import Adam 
TaiwanStockInfo = Load.FinData(dataset = 'TaiwanStockInfo')

def input_data(a,colname):
    print('input data')
    data = Load.FinData(
        dataset = 'TaiwanStockPrice',
        select = str(a),
        date = '2018-11-01')

    #colname = ['date', 'open', 'max', 'min', 'close', 'Trading_Volume']
    #data = data[colname]
    print('select close price')
    date = [ str(d) for d in data['date'] ]
    stock_price = data[colname].values.astype('float32')
    stock_price = stock_price.reshape(len(stock_price), 1)

    print(' 畫圖 ')
    plt.plot(stock_price)
    plt.show()
    
    print(' 取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證 ')
    train_size = int(len(stock_price) * 0.8)
    test_size = len(stock_price) - train_size
    test_size = train_size + int(test_size/2)
    valid_size = test_size

    train = stock_price[:train_size,:]
    test = stock_price[train_size:test_size,:]
    valid = stock_price[valid_size:,:]

    train_date = date[:train_size]
    test_date = date[train_size:test_size]
    valid_date = date[valid_size:]
    return train, test

def process_data(data , n_features,future_days):
    print('切 data')
    dataX, dataY = [], []
    for i in range(len(data)-n_features-future_days):
        a = data[i:(i+n_features), 0]
        dataX.append(a)
        dataY.append(data[i + n_features-1+future_days, 0])
    return np.array(dataX), np.array(dataY)


print('OK')
# Out:
# OK

# %%
# reshape into X=t and Y=t+5
n_features = 5
future_days = 1

# 目標參數 , a
tr, te = input_data(3481,'max')
trainX, trainY = process_data(tr , n_features,future_days)
testX, testY = process_data(te, n_features,future_days)
print(trainX.shape , trainY.shape , testX.shape , testY.shape)

# 其他input
for b in ['min','open','Trading_Volume','close']:
    tr, te = input_data(3481,b)
    train_x, train_y = process_data(tr , n_features,future_days)
    test_x, test_y = process_data(te, n_features,future_days)
    trainX = np.hstack((trainX , train_x))
    #trainY.append(train_y,axis=1)
    testX = np.hstack((testX , test_x))
    #testY.append(test_y,axis=1)

print(trainX.shape , trainY.shape , testX.shape , testY.shape)

# 其他input
for a in [6456,8069,2317]:
    tr, te = input_data(a,'Trading_Volume')
    train_x, train_y = process_data(tr , n_features,future_days)
    test_x, test_y = process_data(te, n_features,future_days)
    trainX = np.hstack((trainX , train_x))
    #trainY.append(train_y,axis=1)
    testX = np.hstack((testX , test_x))
    #testY.append(test_y,axis=1)

print(trainX.shape , trainY.shape , testX.shape , testY.shape)

# 其他input
for a in [6456,8069,2317]:
    tr, te = input_data(a,'max')
    train_x, train_y = process_data(tr , n_features,future_days)
    test_x, test_y = process_data(te, n_features,future_days)
    trainX = np.hstack((trainX , train_x))
    #trainY.append(train_y,axis=1)
    testX = np.hstack((testX , test_x))
    #testY.append(test_y,axis=1)

print(trainX.shape , trainY.shape , testX.shape , testY.shape)



# lstm need input to have 3 dimensions
print('轉換成 LSTM 建模所需 data 的型態')
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print(trainX.shape , trainY.shape , testX.shape , testY.shape)

print(' 歸一化 ')
#scaler = MinMaxScaler(feature_range=(0, 1))
#trainX = scaler.fit_transform(trainX)
#testX = scaler.transform(testX)
trainX = np.log(np.log(trainX))
testX = np.log(np.log(testX))
print(' OK ')
# Out:
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# (297, 5) (297,) (32, 5) (32,)
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# (297, 25) (297,) (32, 25) (32,)
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# (297, 40) (297,) (32, 40) (32,)
# input data
# select close price
#  畫圖
#  取 80% data 當作 training data, 20% data 當作 testing data 做模型驗證
# 切 data
# 切 data
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2b5e5661ed31> in <module>
#      38     train_x, train_y = process_data(tr , n_features,future_days)
#      39     test_x, test_y = process_data(te, n_features,future_days)
# ---> 40     trainX = np.hstack((trainX , train_x))
#      41     #trainY.append(train_y,axis=1)
#      42     testX = np.hstack((testX , test_x))
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     342         return _nx.concatenate(arrs, 0)
#     343     else:
# --> 344         return _nx.concatenate(arrs, 1)
#     345
#     346
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 297 and the array at index 1 has size 291

# %%
'''  set up DL model '''
print('設定參數')
filepath="stock_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')

print('建立 DL 模型，使用 RNN 常見的 GRU and LSTM')
model = Sequential()
model.add(LSTM(256*3 , input_shape = (1 , trainX.shape[2]) , return_sequences=True))
model.add(normalization.BatchNormalization())
model.add(Dropout(0.2))
model.add(LSTM(256*2, return_sequences=True))
model.add(normalization.BatchNormalization())
model.add(Dropout(0.2))
model.add(LSTM(128*1 , return_sequences=True))
model.add(normalization.BatchNormalization())
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64*3 ,  activation = 'relu'))
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(32 ,  activation = 'relu'))
model.add(Dense(15 ,  activation = 'relu'))
model.add(Dense(1))
model.summary()

#model.load_weights('/home/linsam/job/stock_weight.h5')
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])
print('training')
history = model.fit(trainX, trainY, epochs=500 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
print(' save weight ')
model.save_weights('stock_weight.h5')


print('計算 error')
def model_score(model, X_train, y_train, X_test, y_test):
    trainScore = model.evaluate(X_train, y_train, verbose=0)
    print('Train Score: %.5f MSE (%.2f RMSE)' % (trainScore[0], math.sqrt(trainScore[0])))
    testScore = model.evaluate(X_test, y_test, verbose=0)
    print('Test Score: %.5f MSE (%.2f RMSE)' % (testScore[0], math.sqrt(testScore[0])))
    return trainScore[0], testScore[0]

tem = model_score(model, trainX, trainY , testX, testY)


pred = model.predict(testX)
#pred = scaler.inverse_transform(pred)
#pred = np.exp(pred)
print('\n Predicted Stock Prices')
print( pred )

testY2 = testY.reshape(testY.shape[0] , 1)
#testY2 = scaler.inverse_transform(testY2)
print('\n Actual Stock Prices ')
print( testY2 )

print('畫圖')
print("\nRed - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(testY2 , 'b')
plt.plot(pred , 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices')
plt.grid(True)
plt.show()
# Out:
# 設定參數
# 建立 DL 模型，使用 RNN 常見的 GRU and LSTM
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_22 (LSTM)               (None, 1, 768)            2531328
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 1, 768)            3072
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 768)            0
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 1, 512)            2623488
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1, 512)            2048
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 512)            0
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 1, 128)            328192
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 1, 128)            512
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 64)                49408
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 192)               12480
# _________________________________________________________________
# dense_42 (Dense)             (None, 64)                12352
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_44 (Dense)             (None, 15)                495
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 5,565,471
# Trainable params: 5,562,655
# Non-trainable params: 2,816
# _________________________________________________________________
# training
# Train on 297 samples, validate on 32 samples
# Epoch 1/500
# 297/297 [==============================] - 30s 101ms/step - loss: 74.3951 - mean_squared_error: 74.3951 - val_loss: 55.9847 - val_mean_squared_error: 55.9847
#
# Epoch 00001: val_loss improved from -inf to 55.98467, saving model to stock_weights.hdf5
# Epoch 2/500
# 297/297 [==============================] - 0s 752us/step - loss: 71.0794 - mean_squared_error: 71.0794 - val_loss: 55.6493 - val_mean_squared_error: 55.6493
#
# Epoch 00002: val_loss did not improve from 55.98467
# Epoch 3/500
# 297/297 [==============================] - 0s 689us/step - loss: 67.3279 - mean_squared_error: 67.3279 - val_loss: 55.2216 - val_mean_squared_error: 55.2216
#
# Epoch 00003: val_loss did not improve from 55.98467
# Epoch 4/500
# 297/297 [==============================] - 0s 717us/step - loss: 63.0341 - mean_squared_error: 63.0341 - val_loss: 54.6981 - val_mean_squared_error: 54.6981
#
# Epoch 00004: val_loss did not improve from 55.98467
# Epoch 5/500
# 297/297 [==============================] - 0s 667us/step - loss: 57.9612 - mean_squared_error: 57.9612 - val_loss: 54.0532 - val_mean_squared_error: 54.0532
#
# Epoch 00005: val_loss did not improve from 55.98467
# Epoch 6/500
# 297/297 [==============================] - 0s 681us/step - loss: 51.4560 - mean_squared_error: 51.4560 - val_loss: 53.2669 - val_mean_squared_error: 53.2669
#
# Epoch 00006: val_loss did not improve from 55.98467
# Epoch 7/500
# 297/297 [==============================] - 0s 675us/step - loss: 43.3966 - mean_squared_error: 43.3966 - val_loss: 52.2871 - val_mean_squared_error: 52.2871
#
# Epoch 00007: val_loss did not improve from 55.98467
# Epoch 8/500
# 297/297 [==============================] - 0s 719us/step - loss: 34.5518 - mean_squared_error: 34.5518 - val_loss: 51.0567 - val_mean_squared_error: 51.0567
#
# Epoch 00008: val_loss did not improve from 55.98467
# Epoch 9/500
# 297/297 [==============================] - 0s 723us/step - loss: 24.7411 - mean_squared_error: 24.7411 - val_loss: 49.5347 - val_mean_squared_error: 49.5347
#
# Epoch 00009: val_loss did not improve from 55.98467
# Epoch 10/500
# 297/297 [==============================] - 0s 700us/step - loss: 14.2670 - mean_squared_error: 14.2670 - val_loss: 47.6974 - val_mean_squared_error: 47.6974
#
# Epoch 00010: val_loss did not improve from 55.98467
# Epoch 11/500
# 297/297 [==============================] - 0s 726us/step - loss: 5.8161 - mean_squared_error: 5.8161 - val_loss: 45.5237 - val_mean_squared_error: 45.5237
#
# Epoch 00011: val_loss did not improve from 55.98467
# Epoch 12/500
# 297/297 [==============================] - 0s 745us/step - loss: 1.3998 - mean_squared_error: 1.3998 - val_loss: 43.1633 - val_mean_squared_error: 43.1633
#
# Epoch 00012: val_loss did not improve from 55.98467
# Epoch 13/500
# 297/297 [==============================] - 0s 720us/step - loss: 2.4358 - mean_squared_error: 2.4358 - val_loss: 41.2201 - val_mean_squared_error: 41.2201
#
# Epoch 00013: val_loss did not improve from 55.98467
# Epoch 14/500
# 297/297 [==============================] - 0s 724us/step - loss: 3.7043 - mean_squared_error: 3.7043 - val_loss: 40.3309 - val_mean_squared_error: 40.3309
#
# Epoch 00014: val_loss did not improve from 55.98467
# Epoch 15/500
# 297/297 [==============================] - 0s 689us/step - loss: 3.2624 - mean_squared_error: 3.2624 - val_loss: 40.2495 - val_mean_squared_error: 40.2495
#
# Epoch 00015: val_loss did not improve from 55.98467
# Epoch 16/500
# 297/297 [==============================] - 0s 718us/step - loss: 1.4708 - mean_squared_error: 1.4708 - val_loss: 40.4245 - val_mean_squared_error: 40.4245
#
# Epoch 00016: val_loss did not improve from 55.98467
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 17/500
# 297/297 [==============================] - 0s 729us/step - loss: 0.8515 - mean_squared_error: 0.8515 - val_loss: 40.0660 - val_mean_squared_error: 40.0660
#
# Epoch 00017: val_loss did not improve from 55.98467
# Epoch 18/500
# 297/297 [==============================] - 0s 663us/step - loss: 0.8542 - mean_squared_error: 0.8542 - val_loss: 39.6678 - val_mean_squared_error: 39.6678
#
# Epoch 00018: val_loss did not improve from 55.98467
# Epoch 19/500
# 297/297 [==============================] - 0s 686us/step - loss: 0.9240 - mean_squared_error: 0.9240 - val_loss: 39.2698 - val_mean_squared_error: 39.2698
#
# Epoch 00019: val_loss did not improve from 55.98467
# Epoch 20/500
# 297/297 [==============================] - 0s 678us/step - loss: 0.8115 - mean_squared_error: 0.8115 - val_loss: 38.8171 - val_mean_squared_error: 38.8171
#
# Epoch 00020: val_loss did not improve from 55.98467
# Epoch 21/500
# 297/297 [==============================] - 0s 684us/step - loss: 0.7227 - mean_squared_error: 0.7227 - val_loss: 38.4239 - val_mean_squared_error: 38.4239
#
# 297/297 [==============================] - 0s 679us/step - loss: 0.5707 - mean_squared_error: 0.5707 - val_loss: 31.5657 - val_mean_squared_error: 31.5657
#
# Epoch 00036: val_loss did not improve from 55.98467
# Epoch 37/500
# 297/297 [==============================] - 0s 657us/step - loss: 0.8639 - mean_squared_error: 0.8639 - val_loss: 31.0846 - val_mean_squared_error: 31.0846
#
# Epoch 00037: val_loss did not improve from 55.98467
# Epoch 38/500
# 297/297 [==============================] - 0s 690us/step - loss: 0.7943 - mean_squared_error: 0.7943 - val_loss: 30.6369 - val_mean_squared_error: 30.6369
#
# Epoch 00038: val_loss did not improve from 55.98467
# Epoch 39/500
# 297/297 [==============================] - 0s 695us/step - loss: 0.6535 - mean_squared_error: 0.6535 - val_loss: 30.2289 - val_mean_squared_error: 30.2289
#
# Epoch 00039: val_loss did not improve from 55.98467
# Epoch 40/500
# 297/297 [==============================] - 0s 670us/step - loss: 0.7268 - mean_squared_error: 0.7268 - val_loss: 29.7869 - val_mean_squared_error: 29.7869
#
# Epoch 00040: val_loss did not improve from 55.98467
# Epoch 41/500
# 297/297 [==============================] - 0s 700us/step - loss: 0.7674 - mean_squared_error: 0.7674 - val_loss: 29.4179 - val_mean_squared_error: 29.4179
#
# Epoch 00041: val_loss did not improve from 55.98467
# Epoch 42/500
# 297/297 [==============================] - 0s 690us/step - loss: 0.5305 - mean_squared_error: 0.5305 - val_loss: 28.9761 - val_mean_squared_error: 28.9761
#
# Epoch 00042: val_loss did not improve from 55.98467
# Epoch 43/500
# 297/297 [==============================] - 0s 673us/step - loss: 0.7980 - mean_squared_error: 0.7980 - val_loss: 28.5788 - val_mean_squared_error: 28.5788
#
# Epoch 00043: val_loss did not improve from 55.98467
# Epoch 44/500
# 297/297 [==============================] - 0s 631us/step - loss: 0.6827 - mean_squared_error: 0.6827 - val_loss: 28.1602 - val_mean_squared_error: 28.1602
#
# Epoch 00044: val_loss did not improve from 55.98467
# Epoch 45/500
# 297/297 [==============================] - 0s 676us/step - loss: 0.7122 - mean_squared_error: 0.7122 - val_loss: 27.7508 - val_mean_squared_error: 27.7508
#
# Epoch 00045: val_loss did not improve from 55.98467
# Epoch 46/500
# 297/297 [==============================] - 0s 732us/step - loss: 0.7623 - mean_squared_error: 0.7623 - val_loss: 27.3485 - val_mean_squared_error: 27.3485
#
# Epoch 00046: val_loss did not improve from 55.98467
# Epoch 47/500
# 297/297 [==============================] - 0s 695us/step - loss: 0.7484 - mean_squared_error: 0.7484 - val_loss: 26.8697 - val_mean_squared_error: 26.8697
#
# Epoch 00047: val_loss did not improve from 55.98467
# Epoch 48/500
# 297/297 [==============================] - 0s 692us/step - loss: 0.6206 - mean_squared_error: 0.6206 - val_loss: 26.4201 - val_mean_squared_error: 26.4201
#
# Epoch 00048: val_loss did not improve from 55.98467
# Epoch 49/500
# 297/297 [==============================] - 0s 663us/step - loss: 0.7282 - mean_squared_error: 0.7282 - val_loss: 25.9979 - val_mean_squared_error: 25.9979
#
# Epoch 00049: val_loss did not improve from 55.98467
# Epoch 50/500
#
# Epoch 00064: val_loss did not improve from 55.98467
# Epoch 65/500
# 297/297 [==============================] - 0s 676us/step - loss: 0.5693 - mean_squared_error: 0.5693 - val_loss: 20.1733 - val_mean_squared_error: 20.1733
#
# Epoch 00065: val_loss did not improve from 55.98467
# Epoch 66/500
# 297/297 [==============================] - 0s 749us/step - loss: 0.6422 - mean_squared_error: 0.6422 - val_loss: 19.7883 - val_mean_squared_error: 19.7883
#
# Epoch 00066: val_loss did not improve from 55.98467
# Epoch 67/500
# 297/297 [==============================] - 0s 676us/step - loss: 0.5694 - mean_squared_error: 0.5694 - val_loss: 19.4179 - val_mean_squared_error: 19.4179
#
# Epoch 00067: val_loss did not improve from 55.98467
# Epoch 68/500
# 297/297 [==============================] - 0s 654us/step - loss: 0.6512 - mean_squared_error: 0.6512 - val_loss: 19.0037 - val_mean_squared_error: 19.0037
#
# Epoch 00068: val_loss did not improve from 55.98467
# Epoch 69/500
# 297/297 [==============================] - 0s 688us/step - loss: 0.6432 - mean_squared_error: 0.6432 - val_loss: 18.6115 - val_mean_squared_error: 18.6115
#
# Epoch 00069: val_loss did not improve from 55.98467
# Epoch 70/500
# 297/297 [==============================] - 0s 796us/step - loss: 0.6100 - mean_squared_error: 0.6100 - val_loss: 18.2073 - val_mean_squared_error: 18.2073
#
# Epoch 00070: val_loss did not improve from 55.98467
# Epoch 71/500
# 297/297 [==============================] - 0s 707us/step - loss: 0.6244 - mean_squared_error: 0.6244 - val_loss: 17.8255 - val_mean_squared_error: 17.8255
#
# Epoch 00071: val_loss did not improve from 55.98467
# Epoch 72/500
# 297/297 [==============================] - 0s 666us/step - loss: 0.5995 - mean_squared_error: 0.5995 - val_loss: 17.4577 - val_mean_squared_error: 17.4577
#
# Epoch 00072: val_loss did not improve from 55.98467
# Epoch 73/500
# 297/297 [==============================] - 0s 663us/step - loss: 0.7044 - mean_squared_error: 0.7044 - val_loss: 17.1251 - val_mean_squared_error: 17.1251
#
# Epoch 00073: val_loss did not improve from 55.98467
# Epoch 74/500
# 297/297 [==============================] - 0s 690us/step - loss: 0.6425 - mean_squared_error: 0.6425 - val_loss: 16.7727 - val_mean_squared_error: 16.7727
#
# Epoch 00074: val_loss did not improve from 55.98467
# Epoch 75/500
# 297/297 [==============================] - 0s 684us/step - loss: 0.7416 - mean_squared_error: 0.7416 - val_loss: 16.4825 - val_mean_squared_error: 16.4825
#
# Epoch 00075: val_loss did not improve from 55.98467
# Epoch 76/500
# 297/297 [==============================] - 0s 676us/step - loss: 0.6039 - mean_squared_error: 0.6039 - val_loss: 16.1811 - val_mean_squared_error: 16.1811
#
# Epoch 00076: val_loss did not improve from 55.98467
# Epoch 77/500
# 297/297 [==============================] - 0s 668us/step - loss: 0.6572 - mean_squared_error: 0.6572 - val_loss: 15.8881 - val_mean_squared_error: 15.8881
#
# Epoch 00077: val_loss did not improve from 55.98467
# Epoch 78/500
# 297/297 [==============================] - 0s 693us/step - loss: 0.6807 - mean_squared_error: 0.6807 - val_loss: 15.5804 - val_mean_squared_error: 15.5804
#
# Epoch 00078: val_loss did not improve from 55.98467
# Epoch 79/500
# 297/297 [==============================] - 0s 635us/step - loss: 0.6300 - mean_squared_error: 0.6300 - val_loss: 15.3259 - val_mean_squared_error: 15.3259
#
# Epoch 00079: val_loss did not improve from 55.98467
# Epoch 80/500
# 297/297 [==============================] - 0s 677us/step - loss: 0.6858 - mean_squared_error: 0.6858 - val_loss: 15.1383 - val_mean_squared_error: 15.1383
#
# Epoch 00080: val_loss did not improve from 55.98467
# Epoch 81/500
# 297/297 [==============================] - 0s 694us/step - loss: 0.6550 - mean_squared_error: 0.6550 - val_loss: 14.9663 - val_mean_squared_error: 14.9663
#
# Epoch 00081: val_loss did not improve from 55.98467
# Epoch 82/500
# 297/297 [==============================] - 0s 690us/step - loss: 0.6224 - mean_squared_error: 0.6224 - val_loss: 14.7969 - val_mean_squared_error: 14.7969
#
# Epoch 00082: val_loss did not improve from 55.98467
# Epoch 83/500
# 297/297 [==============================] - 0s 705us/step - loss: 0.6916 - mean_squared_error: 0.6916 - val_loss: 14.6322 - val_mean_squared_error: 14.6322
#
# Epoch 00083: val_loss did not improve from 55.98467
# Epoch 84/500
# 297/297 [==============================] - 0s 677us/step - loss: 0.6290 - mean_squared_error: 0.6290 - val_loss: 14.4263 - val_mean_squared_error: 14.4263
#
# Epoch 00084: val_loss did not improve from 55.98467
# Epoch 85/500
# 297/297 [==============================] - 0s 663us/step - loss: 0.5879 - mean_squared_error: 0.5879 - val_loss: 14.2048 - val_mean_squared_error: 14.2048
#
# Epoch 00085: val_loss did not improve from 55.98467
# Epoch 86/500
# 297/297 [==============================] - 0s 643us/step - loss: 0.7068 - mean_squared_error: 0.7068 - val_loss: 13.9717 - val_mean_squared_error: 13.9717
#
# Epoch 00086: val_loss did not improve from 55.98467
# Epoch 87/500
# 297/297 [==============================] - 0s 675us/step - loss: 0.6611 - mean_squared_error: 0.6611 - val_loss: 13.6907 - val_mean_squared_error: 13.6907
#
# Epoch 00087: val_loss did not improve from 55.98467
# Epoch 88/500
# 297/297 [==============================] - 0s 681us/step - loss: 0.6735 - mean_squared_error: 0.6735 - val_loss: 13.4644 - val_mean_squared_error: 13.4644
#
# Epoch 00088: val_loss did not improve from 55.98467
# Epoch 89/500
# 297/297 [==============================] - 0s 663us/step - loss: 0.6663 - mean_squared_error: 0.6663 - val_loss: 13.3024 - val_mean_squared_error: 13.3024
#
# Epoch 00089: val_loss did not improve from 55.98467
# Epoch 90/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.6746 - mean_squared_error: 0.6746 - val_loss: 13.1444 - val_mean_squared_error: 13.1444
#
# Epoch 00090: val_loss did not improve from 55.98467
# Epoch 91/500
# 297/297 [==============================] - 0s 718us/step - loss: 0.5857 - mean_squared_error: 0.5857 - val_loss: 12.9573 - val_mean_squared_error: 12.9573
#
# Epoch 00091: val_loss did not improve from 55.98467
# Epoch 92/500
# 297/297 [==============================] - 0s 696us/step - loss: 0.7314 - mean_squared_error: 0.7314 - val_loss: 12.7473 - val_mean_squared_error: 12.7473
#
# Epoch 00092: val_loss did not improve from 55.98467
# Epoch 93/500
#
# Epoch 00121: val_loss did not improve from 55.98467
# Epoch 122/500
# 297/297 [==============================] - 0s 711us/step - loss: 0.5838 - mean_squared_error: 0.5838 - val_loss: 7.4526 - val_mean_squared_error: 7.4526
#
# Epoch 00122: val_loss did not improve from 55.98467
# Epoch 123/500
# 297/297 [==============================] - 0s 696us/step - loss: 0.5988 - mean_squared_error: 0.5988 - val_loss: 7.3603 - val_mean_squared_error: 7.3603
#
# Epoch 00123: val_loss did not improve from 55.98467
# Epoch 124/500
# 297/297 [==============================] - 0s 669us/step - loss: 0.4726 - mean_squared_error: 0.4726 - val_loss: 7.2446 - val_mean_squared_error: 7.2446
#
# Epoch 00124: val_loss did not improve from 55.98467
# Epoch 125/500
# 297/297 [==============================] - 0s 660us/step - loss: 0.6105 - mean_squared_error: 0.6105 - val_loss: 7.1064 - val_mean_squared_error: 7.1064
#
# Epoch 00125: val_loss did not improve from 55.98467
# Epoch 126/500
# 297/297 [==============================] - 0s 684us/step - loss: 0.5435 - mean_squared_error: 0.5435 - val_loss: 6.9437 - val_mean_squared_error: 6.9437
#
# Epoch 00126: val_loss did not improve from 55.98467
# Epoch 127/500
# 297/297 [==============================] - 0s 733us/step - loss: 0.6423 - mean_squared_error: 0.6423 - val_loss: 6.7718 - val_mean_squared_error: 6.7718
#
# Epoch 00127: val_loss did not improve from 55.98467
# Epoch 128/500
# 297/297 [==============================] - 0s 746us/step - loss: 0.5264 - mean_squared_error: 0.5264 - val_loss: 6.5967 - val_mean_squared_error: 6.5967
#
# Epoch 00128: val_loss did not improve from 55.98467
# Epoch 129/500
# 297/297 [==============================] - 0s 673us/step - loss: 0.5447 - mean_squared_error: 0.5447 - val_loss: 6.4609 - val_mean_squared_error: 6.4609
#
# Epoch 00129: val_loss did not improve from 55.98467
# Epoch 130/500
# 297/297 [==============================] - 0s 665us/step - loss: 0.6113 - mean_squared_error: 0.6113 - val_loss: 6.3953 - val_mean_squared_error: 6.3953
#
# Epoch 00130: val_loss did not improve from 55.98467
# Epoch 131/500
# 297/297 [==============================] - 0s 664us/step - loss: 0.5195 - mean_squared_error: 0.5195 - val_loss: 6.3116 - val_mean_squared_error: 6.3116
#
# Epoch 00131: val_loss did not improve from 55.98467
# Epoch 132/500
# 297/297 [==============================] - 0s 688us/step - loss: 0.6527 - mean_squared_error: 0.6527 - val_loss: 6.2410 - val_mean_squared_error: 6.2410
#
# Epoch 00132: val_loss did not improve from 55.98467
# Epoch 133/500
# 297/297 [==============================] - 0s 695us/step - loss: 0.6444 - mean_squared_error: 0.6444 - val_loss: 6.1727 - val_mean_squared_error: 6.1727
#
# Epoch 00133: val_loss did not improve from 55.98467
# Epoch 134/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.5816 - mean_squared_error: 0.5816 - val_loss: 6.0985 - val_mean_squared_error: 6.0985
#
# Epoch 00134: val_loss did not improve from 55.98467
# Epoch 135/500
# 297/297 [==============================] - 0s 806us/step - loss: 0.6047 - mean_squared_error: 0.6047 - val_loss: 6.0364 - val_mean_squared_error: 6.0364
#
# Epoch 00135: val_loss did not improve from 55.98467
# Epoch 136/500
# 297/297 [==============================] - 0s 709us/step - loss: 0.6246 - mean_squared_error: 0.6246 - val_loss: 6.0204 - val_mean_squared_error: 6.0204
#
# Epoch 00136: val_loss did not improve from 55.98467
# Epoch 137/500
# 297/297 [==============================] - 0s 676us/step - loss: 0.4976 - mean_squared_error: 0.4976 - val_loss: 6.0397 - val_mean_squared_error: 6.0397
#
# Epoch 00137: val_loss did not improve from 55.98467
#
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# Epoch 138/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.6879 - mean_squared_error: 0.6879 - val_loss: 5.9284 - val_mean_squared_error: 5.9284
#
# Epoch 00138: val_loss did not improve from 55.98467
# Epoch 139/500
# 297/297 [==============================] - 0s 664us/step - loss: 0.6319 - mean_squared_error: 0.6319 - val_loss: 5.8160 - val_mean_squared_error: 5.8160
#
# Epoch 00139: val_loss did not improve from 55.98467
# Epoch 140/500
# 297/297 [==============================] - 0s 667us/step - loss: 0.5409 - mean_squared_error: 0.5409 - val_loss: 5.7178 - val_mean_squared_error: 5.7178
#
# Epoch 00140: val_loss did not improve from 55.98467
# Epoch 141/500
# 297/297 [==============================] - 0s 694us/step - loss: 0.5717 - mean_squared_error: 0.5717 - val_loss: 5.6171 - val_mean_squared_error: 5.6171
#
# Epoch 00141: val_loss did not improve from 55.98467
# Epoch 142/500
# 297/297 [==============================] - 0s 654us/step - loss: 0.6824 - mean_squared_error: 0.6824 - val_loss: 5.5048 - val_mean_squared_error: 5.5048
#
# Epoch 00142: val_loss did not improve from 55.98467
# Epoch 143/500
# 297/297 [==============================] - 0s 632us/step - loss: 0.5271 - mean_squared_error: 0.5271 - val_loss: 5.4002 - val_mean_squared_error: 5.4002
#
# Epoch 00143: val_loss did not improve from 55.98467
# Epoch 144/500
# 297/297 [==============================] - 0s 653us/step - loss: 0.5745 - mean_squared_error: 0.5745 - val_loss: 5.3008 - val_mean_squared_error: 5.3008
#
# Epoch 00144: val_loss did not improve from 55.98467
# Epoch 145/500
# 297/297 [==============================] - 0s 689us/step - loss: 0.5599 - mean_squared_error: 0.5599 - val_loss: 5.2009 - val_mean_squared_error: 5.2009
#
# Epoch 00145: val_loss did not improve from 55.98467
# Epoch 146/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.5276 - mean_squared_error: 0.5276 - val_loss: 5.0958 - val_mean_squared_error: 5.0958
#
# Epoch 00146: val_loss did not improve from 55.98467
# Epoch 147/500
# 297/297 [==============================] - 0s 639us/step - loss: 0.5775 - mean_squared_error: 0.5775 - val_loss: 4.9976 - val_mean_squared_error: 4.9976
#
# Epoch 00147: val_loss did not improve from 55.98467
# Epoch 148/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.5969 - mean_squared_error: 0.5969 - val_loss: 4.8969 - val_mean_squared_error: 4.8969
#
# Epoch 00148: val_loss did not improve from 55.98467
# Epoch 149/500
# 297/297 [==============================] - 0s 675us/step - loss: 0.6232 - mean_squared_error: 0.6232 - val_loss: 4.7973 - val_mean_squared_error: 4.7973
# Epoch 164/500
# 297/297 [==============================] - 0s 659us/step - loss: 0.7366 - mean_squared_error: 0.7366 - val_loss: 3.3138 - val_mean_squared_error: 3.3138
#
# Epoch 00164: val_loss did not improve from 55.98467
# Epoch 165/500
# 297/297 [==============================] - 0s 698us/step - loss: 0.5561 - mean_squared_error: 0.5561 - val_loss: 3.2296 - val_mean_squared_error: 3.2296
#
# Epoch 00165: val_loss did not improve from 55.98467
# Epoch 166/500
# 297/297 [==============================] - 0s 698us/step - loss: 0.6553 - mean_squared_error: 0.6553 - val_loss: 3.1475 - val_mean_squared_error: 3.1475
#
# Epoch 00166: val_loss did not improve from 55.98467
# Epoch 167/500
# 297/297 [==============================] - 0s 681us/step - loss: 0.5955 - mean_squared_error: 0.5955 - val_loss: 3.0584 - val_mean_squared_error: 3.0584
#
# Epoch 00167: val_loss did not improve from 55.98467
# Epoch 168/500
# 297/297 [==============================] - 0s 692us/step - loss: 0.5650 - mean_squared_error: 0.5650 - val_loss: 2.9775 - val_mean_squared_error: 2.9775
#
# Epoch 00168: val_loss did not improve from 55.98467
# Epoch 169/500
# 297/297 [==============================] - 0s 647us/step - loss: 0.5459 - mean_squared_error: 0.5459 - val_loss: 2.8938 - val_mean_squared_error: 2.8938
#
# Epoch 00169: val_loss did not improve from 55.98467
# Epoch 170/500
# 297/297 [==============================] - 0s 667us/step - loss: 0.5455 - mean_squared_error: 0.5455 - val_loss: 2.7998 - val_mean_squared_error: 2.7998
#
# Epoch 00170: val_loss did not improve from 55.98467
# Epoch 171/500
# 297/297 [==============================] - 0s 678us/step - loss: 0.6009 - mean_squared_error: 0.6009 - val_loss: 2.7146 - val_mean_squared_error: 2.7146
#
# Epoch 00171: val_loss did not improve from 55.98467
# Epoch 172/500
# 297/297 [==============================] - 0s 680us/step - loss: 0.6098 - mean_squared_error: 0.6098 - val_loss: 2.6317 - val_mean_squared_error: 2.6317
#
# Epoch 00172: val_loss did not improve from 55.98467
# Epoch 173/500
# 297/297 [==============================] - 0s 658us/step - loss: 0.6267 - mean_squared_error: 0.6267 - val_loss: 2.5526 - val_mean_squared_error: 2.5526
#
# Epoch 00173: val_loss did not improve from 55.98467
# Epoch 174/500
# 297/297 [==============================] - 0s 690us/step - loss: 0.5702 - mean_squared_error: 0.5702 - val_loss: 2.4876 - val_mean_squared_error: 2.4876
#
# Epoch 00174: val_loss did not improve from 55.98467
# Epoch 175/500
# 297/297 [==============================] - 0s 672us/step - loss: 0.5984 - mean_squared_error: 0.5984 - val_loss: 2.4206 - val_mean_squared_error: 2.4206
#
# Epoch 00175: val_loss did not improve from 55.98467
# Epoch 176/500
# 297/297 [==============================] - 0s 702us/step - loss: 0.7430 - mean_squared_error: 0.7430 - val_loss: 2.3505 - val_mean_squared_error: 2.3505
#
# Epoch 00176: val_loss did not improve from 55.98467
# Epoch 177/500
# 297/297 [==============================] - 0s 653us/step - loss: 0.5576 - mean_squared_error: 0.5576 - val_loss: 2.2764 - val_mean_squared_error: 2.2764
#
# Epoch 00177: val_loss did not improve from 55.98467
# Epoch 178/500
# 297/297 [==============================] - 0s 709us/step - loss: 0.6691 - mean_squared_error: 0.6691 - val_loss: 2.2162 - val_mean_squared_error: 2.2162
#
# Epoch 00178: val_loss did not improve from 55.98467
# Epoch 179/500
# 297/297 [==============================] - 0s 659us/step - loss: 0.6481 - mean_squared_error: 0.6481 - val_loss: 2.1543 - val_mean_squared_error: 2.1543
#
# Epoch 00179: val_loss did not improve from 55.98467
# Epoch 180/500
# 297/297 [==============================] - 0s 641us/step - loss: 0.5452 - mean_squared_error: 0.5452 - val_loss: 2.0915 - val_mean_squared_error: 2.0915
#
# Epoch 00180: val_loss did not improve from 55.98467
# Epoch 181/500
# 297/297 [==============================] - 0s 678us/step - loss: 0.6031 - mean_squared_error: 0.6031 - val_loss: 2.0275 - val_mean_squared_error: 2.0275
#
# Epoch 00181: val_loss did not improve from 55.98467
# Epoch 182/500
# 297/297 [==============================] - 0s 675us/step - loss: 0.5991 - mean_squared_error: 0.5991 - val_loss: 1.9723 - val_mean_squared_error: 1.9723
#
# Epoch 00182: val_loss did not improve from 55.98467
# Epoch 183/500
# 297/297 [==============================] - 0s 712us/step - loss: 0.5914 - mean_squared_error: 0.5914 - val_loss: 1.9250 - val_mean_squared_error: 1.9250
#
# Epoch 00183: val_loss did not improve from 55.98467
# Epoch 184/500
# 297/297 [==============================] - 0s 672us/step - loss: 0.5860 - mean_squared_error: 0.5860 - val_loss: 1.8764 - val_mean_squared_error: 1.8764
#
# Epoch 00184: val_loss did not improve from 55.98467
# Epoch 185/500
# 297/297 [==============================] - 0s 682us/step - loss: 0.5197 - mean_squared_error: 0.5197 - val_loss: 1.8207 - val_mean_squared_error: 1.8207
#
# Epoch 00185: val_loss did not improve from 55.98467
# Epoch 186/500
# 297/297 [==============================] - 0s 633us/step - loss: 0.6479 - mean_squared_error: 0.6479 - val_loss: 1.7707 - val_mean_squared_error: 1.7707
#
# Epoch 00186: val_loss did not improve from 55.98467
# Epoch 187/500
# 297/297 [==============================] - 0s 669us/step - loss: 0.6513 - mean_squared_error: 0.6513 - val_loss: 1.7131 - val_mean_squared_error: 1.7131
#
# Epoch 00187: val_loss did not improve from 55.98467
# Epoch 188/500
# 297/297 [==============================] - 0s 642us/step - loss: 0.5327 - mean_squared_error: 0.5327 - val_loss: 1.6725 - val_mean_squared_error: 1.6725
#
# Epoch 00188: val_loss did not improve from 55.98467
# Epoch 189/500
# 297/297 [==============================] - 0s 675us/step - loss: 0.5352 - mean_squared_error: 0.5352 - val_loss: 1.6340 - val_mean_squared_error: 1.6340
#
# Epoch 00189: val_loss did not improve from 55.98467
# Epoch 190/500
# 297/297 [==============================] - 0s 631us/step - loss: 0.5957 - mean_squared_error: 0.5957 - val_loss: 1.5936 - val_mean_squared_error: 1.5936
#
# Epoch 00190: val_loss did not improve from 55.98467
# Epoch 191/500
# 297/297 [==============================] - 0s 643us/step - loss: 0.5515 - mean_squared_error: 0.5515 - val_loss: 1.5363 - val_mean_squared_error: 1.5363
#
# Epoch 00191: val_loss did not improve from 55.98467
# Epoch 192/500
# 297/297 [==============================] - 0s 687us/step - loss: 0.6712 - mean_squared_error: 0.6712 - val_loss: 1.4736 - val_mean_squared_error: 1.4736
#
# Epoch 00192: val_loss did not improve from 55.98467
# Epoch 193/500
# 297/297 [==============================] - 0s 693us/step - loss: 0.5661 - mean_squared_error: 0.5661 - val_loss: 1.4290 - val_mean_squared_error: 1.4290
#
# Epoch 00193: val_loss did not improve from 55.98467
# Epoch 194/500
# 297/297 [==============================] - 0s 675us/step - loss: 0.5652 - mean_squared_error: 0.5652 - val_loss: 1.3786 - val_mean_squared_error: 1.3786
#
# Epoch 00194: val_loss did not improve from 55.98467
# Epoch 195/500
# 297/297 [==============================] - 0s 685us/step - loss: 0.5436 - mean_squared_error: 0.5436 - val_loss: 1.3326 - val_mean_squared_error: 1.3326
#
# Epoch 00195: val_loss did not improve from 55.98467
# Epoch 196/500
# 297/297 [==============================] - 0s 680us/step - loss: 0.5915 - mean_squared_error: 0.5915 - val_loss: 1.2901 - val_mean_squared_error: 1.2901
#
# Epoch 00196: val_loss did not improve from 55.98467
# Epoch 197/500
# 297/297 [==============================] - 0s 669us/step - loss: 0.5285 - mean_squared_error: 0.5285 - val_loss: 1.2538 - val_mean_squared_error: 1.2538
#
# Epoch 00197: val_loss did not improve from 55.98467
# Epoch 198/500
# 297/297 [==============================] - 0s 649us/step - loss: 0.5841 - mean_squared_error: 0.5841 - val_loss: 1.2198 - val_mean_squared_error: 1.2198
#
# Epoch 00198: val_loss did not improve from 55.98467
# Epoch 199/500
# 297/297 [==============================] - 0s 713us/step - loss: 0.5997 - mean_squared_error: 0.5997 - val_loss: 1.1849 - val_mean_squared_error: 1.1849
#
# Epoch 00199: val_loss did not improve from 55.98467
# Epoch 200/500
# 297/297 [==============================] - 0s 683us/step - loss: 0.5516 - mean_squared_error: 0.5516 - val_loss: 1.1498 - val_mean_squared_error: 1.1498
#
# Epoch 00200: val_loss did not improve from 55.98467
# Epoch 201/500
# 297/297 [==============================] - 0s 657us/step - loss: 0.5573 - mean_squared_error: 0.5573 - val_loss: 1.1173 - val_mean_squared_error: 1.1173
#
# Epoch 00201: val_loss did not improve from 55.98467
# Epoch 202/500
# 297/297 [==============================] - 0s 686us/step - loss: 0.5876 - mean_squared_error: 0.5876 - val_loss: 1.0770 - val_mean_squared_error: 1.0770
#
# Epoch 00202: val_loss did not improve from 55.98467
# Epoch 203/500
# 297/297 [==============================] - 0s 651us/step - loss: 0.6764 - mean_squared_error: 0.6764 - val_loss: 1.0580 - val_mean_squared_error: 1.0580
#
# Epoch 00203: val_loss did not improve from 55.98467
# Epoch 204/500
# 297/297 [==============================] - 0s 673us/step - loss: 0.4795 - mean_squared_error: 0.4795 - val_loss: 1.0294 - val_mean_squared_error: 1.0294
#
# Epoch 00204: val_loss did not improve from 55.98467
# Epoch 205/500
# 297/297 [==============================] - 0s 679us/step - loss: 0.5480 - mean_squared_error: 0.5480 - val_loss: 1.0001 - val_mean_squared_error: 1.0001
#
# Epoch 00205: val_loss did not improve from 55.98467
# Epoch 206/500
# ...
#
# Epoch 00432: val_loss did not improve from 55.98467
# Epoch 433/500
# 297/297 [==============================] - 0s 490us/step - loss: 0.5023 - mean_squared_error: 0.5023 - val_loss: 0.2648 - val_mean_squared_error: 0.2648
#
# Epoch 00433: val_loss did not improve from 55.98467
# Epoch 434/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.6389 - mean_squared_error: 0.6389 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
#
# Epoch 00434: val_loss did not improve from 55.98467
# Epoch 435/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.5548 - mean_squared_error: 0.5548 - val_loss: 0.2634 - val_mean_squared_error: 0.2634
#
# Epoch 00435: val_loss did not improve from 55.98467
# Epoch 436/500
# 297/297 [==============================] - 0s 477us/step - loss: 0.6109 - mean_squared_error: 0.6109 - val_loss: 0.2628 - val_mean_squared_error: 0.2628
#
# Epoch 00436: val_loss did not improve from 55.98467
# Epoch 437/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.5382 - mean_squared_error: 0.5382 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
#
# Epoch 00437: val_loss did not improve from 55.98467
# Epoch 438/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5672 - mean_squared_error: 0.5672 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
#
# Epoch 00438: val_loss did not improve from 55.98467
# Epoch 439/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.6362 - mean_squared_error: 0.6362 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
#
# Epoch 00439: val_loss did not improve from 55.98467
# Epoch 440/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.6699 - mean_squared_error: 0.6699 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
#
# Epoch 00440: val_loss did not improve from 55.98467
# Epoch 441/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.5778 - mean_squared_error: 0.5778 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
#
# Epoch 00441: val_loss did not improve from 55.98467
# Epoch 442/500
# 297/297 [==============================] - 0s 457us/step - loss: 0.5073 - mean_squared_error: 0.5073 - val_loss: 0.2631 - val_mean_squared_error: 0.2631
#
# Epoch 00442: val_loss did not improve from 55.98467
# Epoch 443/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5455 - mean_squared_error: 0.5455 - val_loss: 0.2632 - val_mean_squared_error: 0.2632
#
# Epoch 00443: val_loss did not improve from 55.98467
# Epoch 444/500
# 297/297 [==============================] - 0s 462us/step - loss: 0.4909 - mean_squared_error: 0.4909 - val_loss: 0.2628 - val_mean_squared_error: 0.2628
#
# Epoch 00444: val_loss did not improve from 55.98467
# Epoch 445/500
# 297/297 [==============================] - 0s 474us/step - loss: 0.4949 - mean_squared_error: 0.4949 - val_loss: 0.2630 - val_mean_squared_error: 0.2630
#
# Epoch 00445: val_loss did not improve from 55.98467
# Epoch 446/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.6395 - mean_squared_error: 0.6395 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
#
# Epoch 00446: val_loss did not improve from 55.98467
# Epoch 447/500
# 297/297 [==============================] - 0s 479us/step - loss: 0.4747 - mean_squared_error: 0.4747 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
#
# Epoch 00447: val_loss did not improve from 55.98467
# Epoch 448/500
# 297/297 [==============================] - 0s 459us/step - loss: 0.5579 - mean_squared_error: 0.5579 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
#
# Epoch 00448: val_loss did not improve from 55.98467
# Epoch 449/500
# 297/297 [==============================] - 0s 474us/step - loss: 0.5218 - mean_squared_error: 0.5218 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
#
# Epoch 00449: val_loss did not improve from 55.98467
# Epoch 450/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.5294 - mean_squared_error: 0.5294 - val_loss: 0.2582 - val_mean_squared_error: 0.2582
#
# Epoch 00450: val_loss did not improve from 55.98467
# Epoch 451/500
# 297/297 [==============================] - 0s 472us/step - loss: 0.5656 - mean_squared_error: 0.5656 - val_loss: 0.2576 - val_mean_squared_error: 0.2576
#
# Epoch 00451: val_loss did not improve from 55.98467
# Epoch 452/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5646 - mean_squared_error: 0.5646 - val_loss: 0.2568 - val_mean_squared_error: 0.2568
#
# Epoch 00452: val_loss did not improve from 55.98467
# Epoch 453/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5255 - mean_squared_error: 0.5255 - val_loss: 0.2556 - val_mean_squared_error: 0.2556
#
# Epoch 00453: val_loss did not improve from 55.98467
# Epoch 454/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.6254 - mean_squared_error: 0.6254 - val_loss: 0.2562 - val_mean_squared_error: 0.2562
#
# Epoch 00454: val_loss did not improve from 55.98467
# Epoch 455/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.5108 - mean_squared_error: 0.5108 - val_loss: 0.2554 - val_mean_squared_error: 0.2554
#
# Epoch 00455: val_loss did not improve from 55.98467
# Epoch 456/500
# 297/297 [==============================] - 0s 477us/step - loss: 0.6436 - mean_squared_error: 0.6436 - val_loss: 0.2557 - val_mean_squared_error: 0.2557
#
# Epoch 00456: val_loss did not improve from 55.98467
# Epoch 457/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.5640 - mean_squared_error: 0.5640 - val_loss: 0.2563 - val_mean_squared_error: 0.2563
#
# Epoch 00457: val_loss did not improve from 55.98467
# Epoch 458/500
# 297/297 [==============================] - 0s 473us/step - loss: 0.5235 - mean_squared_error: 0.5235 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
#
# Epoch 00458: val_loss did not improve from 55.98467
# Epoch 459/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.6562 - mean_squared_error: 0.6562 - val_loss: 0.2562 - val_mean_squared_error: 0.2562
#
# Epoch 00459: val_loss did not improve from 55.98467
# Epoch 460/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5323 - mean_squared_error: 0.5323 - val_loss: 0.2568 - val_mean_squared_error: 0.2568
#
# Epoch 00460: val_loss did not improve from 55.98467
# Epoch 461/500
# 297/297 [==============================] - 0s 466us/step - loss: 0.5317 - mean_squared_error: 0.5317 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
#
# Epoch 00461: val_loss did not improve from 55.98467
# Epoch 462/500
# 297/297 [==============================] - 0s 474us/step - loss: 0.5261 - mean_squared_error: 0.5261 - val_loss: 0.2557 - val_mean_squared_error: 0.2557
#
# Epoch 00462: val_loss did not improve from 55.98467
# Epoch 463/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.6508 - mean_squared_error: 0.6508 - val_loss: 0.2564 - val_mean_squared_error: 0.2564
#
# Epoch 00463: val_loss did not improve from 55.98467
# Epoch 464/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.5149 - mean_squared_error: 0.5149 - val_loss: 0.2555 - val_mean_squared_error: 0.2555
#
# Epoch 00464: val_loss did not improve from 55.98467
# Epoch 465/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.6609 - mean_squared_error: 0.6609 - val_loss: 0.2545 - val_mean_squared_error: 0.2545
#
# Epoch 00465: val_loss did not improve from 55.98467
# Epoch 466/500
# 297/297 [==============================] - 0s 457us/step - loss: 0.5026 - mean_squared_error: 0.5026 - val_loss: 0.2544 - val_mean_squared_error: 0.2544
#
# Epoch 00466: val_loss did not improve from 55.98467
# Epoch 467/500
# 297/297 [==============================] - 0s 473us/step - loss: 0.5362 - mean_squared_error: 0.5362 - val_loss: 0.2527 - val_mean_squared_error: 0.2527
#
# Epoch 00467: val_loss did not improve from 55.98467
# Epoch 468/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.5569 - mean_squared_error: 0.5569 - val_loss: 0.2517 - val_mean_squared_error: 0.2517
#
# Epoch 00468: val_loss did not improve from 55.98467
# Epoch 469/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5612 - mean_squared_error: 0.5612 - val_loss: 0.2510 - val_mean_squared_error: 0.2510
#
# Epoch 00469: val_loss did not improve from 55.98467
# Epoch 470/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.6032 - mean_squared_error: 0.6032 - val_loss: 0.2513 - val_mean_squared_error: 0.2513
#
# Epoch 00470: val_loss did not improve from 55.98467
# Epoch 471/500
# 297/297 [==============================] - 0s 469us/step - loss: 0.5825 - mean_squared_error: 0.5825 - val_loss: 0.2500 - val_mean_squared_error: 0.2500
#
# Epoch 00471: val_loss did not improve from 55.98467
# Epoch 472/500
# 297/297 [==============================] - 0s 462us/step - loss: 0.6204 - mean_squared_error: 0.6204 - val_loss: 0.2495 - val_mean_squared_error: 0.2495
#
# Epoch 00472: val_loss did not improve from 55.98467
# Epoch 473/500
# 297/297 [==============================] - 0s 474us/step - loss: 0.5293 - mean_squared_error: 0.5293 - val_loss: 0.2519 - val_mean_squared_error: 0.2519
#
# Epoch 00473: val_loss did not improve from 55.98467
# Epoch 474/500
# 297/297 [==============================] - 0s 473us/step - loss: 0.5885 - mean_squared_error: 0.5885 - val_loss: 0.2523 - val_mean_squared_error: 0.2523
#
# Epoch 00474: val_loss did not improve from 55.98467
# Epoch 475/500
# 297/297 [==============================] - 0s 490us/step - loss: 0.5350 - mean_squared_error: 0.5350 - val_loss: 0.2525 - val_mean_squared_error: 0.2525
#
# Epoch 00475: val_loss did not improve from 55.98467
# Epoch 476/500
# 297/297 [==============================] - 0s 490us/step - loss: 0.6150 - mean_squared_error: 0.6150 - val_loss: 0.2539 - val_mean_squared_error: 0.2539
#
# Epoch 00476: val_loss did not improve from 55.98467
# Epoch 477/500
# 297/297 [==============================] - 0s 490us/step - loss: 0.5857 - mean_squared_error: 0.5857 - val_loss: 0.2538 - val_mean_squared_error: 0.2538
#
# Epoch 00477: val_loss did not improve from 55.98467
# Epoch 478/500
# 297/297 [==============================] - 0s 484us/step - loss: 0.5810 - mean_squared_error: 0.5810 - val_loss: 0.2540 - val_mean_squared_error: 0.2540
#
# Epoch 00478: val_loss did not improve from 55.98467
# Epoch 479/500
# 297/297 [==============================] - 0s 484us/step - loss: 0.6025 - mean_squared_error: 0.6025 - val_loss: 0.2573 - val_mean_squared_error: 0.2573
#
# Epoch 00479: val_loss did not improve from 55.98467
# Epoch 480/500
# 297/297 [==============================] - 0s 473us/step - loss: 0.5430 - mean_squared_error: 0.5430 - val_loss: 0.2565 - val_mean_squared_error: 0.2565
#
# Epoch 00480: val_loss did not improve from 55.98467
# Epoch 481/500
# 297/297 [==============================] - 0s 473us/step - loss: 0.6265 - mean_squared_error: 0.6265 - val_loss: 0.2550 - val_mean_squared_error: 0.2550
#
# Epoch 00481: val_loss did not improve from 55.98467
# Epoch 482/500
# 297/297 [==============================] - 0s 465us/step - loss: 0.5961 - mean_squared_error: 0.5961 - val_loss: 0.2548 - val_mean_squared_error: 0.2548
#
# Epoch 00482: val_loss did not improve from 55.98467
# Epoch 483/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.5009 - mean_squared_error: 0.5009 - val_loss: 0.2533 - val_mean_squared_error: 0.2533
#
# Epoch 00483: val_loss did not improve from 55.98467
# Epoch 484/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5117 - mean_squared_error: 0.5117 - val_loss: 0.2530 - val_mean_squared_error: 0.2530
#
# Epoch 00484: val_loss did not improve from 55.98467
# Epoch 485/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.4497 - mean_squared_error: 0.4497 - val_loss: 0.2525 - val_mean_squared_error: 0.2525
#
# Epoch 00485: val_loss did not improve from 55.98467
# Epoch 486/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.6011 - mean_squared_error: 0.6011 - val_loss: 0.2502 - val_mean_squared_error: 0.2502
#
# Epoch 00486: val_loss did not improve from 55.98467
# Epoch 487/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5442 - mean_squared_error: 0.5442 - val_loss: 0.2490 - val_mean_squared_error: 0.2490
#
# Epoch 00487: val_loss did not improve from 55.98467
# Epoch 488/500
# 297/297 [==============================] - 0s 467us/step - loss: 0.5645 - mean_squared_error: 0.5645 - val_loss: 0.2485 - val_mean_squared_error: 0.2485
#
# Epoch 00488: val_loss did not improve from 55.98467
# Epoch 489/500
# 297/297 [==============================] - 0s 463us/step - loss: 0.6305 - mean_squared_error: 0.6305 - val_loss: 0.2479 - val_mean_squared_error: 0.2479
#
# Epoch 00489: val_loss did not improve from 55.98467
# Epoch 490/500
# 297/297 [==============================] - 0s 470us/step - loss: 0.5331 - mean_squared_error: 0.5331 - val_loss: 0.2503 - val_mean_squared_error: 0.2503
#
# Epoch 00490: val_loss did not improve from 55.98467
# Epoch 491/500
# 297/297 [==============================] - 0s 465us/step - loss: 0.5670 - mean_squared_error: 0.5670 - val_loss: 0.2520 - val_mean_squared_error: 0.2520
#
# Epoch 00491: val_loss did not improve from 55.98467
# Epoch 492/500
# 297/297 [==============================] - 0s 472us/step - loss: 0.5565 - mean_squared_error: 0.5565 - val_loss: 0.2540 - val_mean_squared_error: 0.2540
#
# Epoch 00492: val_loss did not improve from 55.98467
# Epoch 493/500
# 297/297 [==============================] - 0s 458us/step - loss: 0.6406 - mean_squared_error: 0.6406 - val_loss: 0.2523 - val_mean_squared_error: 0.2523
#
# Epoch 00493: val_loss did not improve from 55.98467
# Epoch 494/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.6511 - mean_squared_error: 0.6511 - val_loss: 0.2504 - val_mean_squared_error: 0.2504
#
# Epoch 00494: val_loss did not improve from 55.98467
# Epoch 495/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.5484 - mean_squared_error: 0.5484 - val_loss: 0.2515 - val_mean_squared_error: 0.2515
#
# Epoch 00495: val_loss did not improve from 55.98467
# Epoch 496/500
# 297/297 [==============================] - 0s 457us/step - loss: 0.5342 - mean_squared_error: 0.5342 - val_loss: 0.2495 - val_mean_squared_error: 0.2495
#
# Epoch 00496: val_loss did not improve from 55.98467
# Epoch 497/500
# 297/297 [==============================] - 0s 464us/step - loss: 0.5507 - mean_squared_error: 0.5507 - val_loss: 0.2486 - val_mean_squared_error: 0.2486
#
# Epoch 00497: val_loss did not improve from 55.98467
# Epoch 498/500
# 297/297 [==============================] - 0s 460us/step - loss: 0.6131 - mean_squared_error: 0.6131 - val_loss: 0.2483 - val_mean_squared_error: 0.2483
#
# Epoch 00498: val_loss did not improve from 55.98467
# Epoch 499/500
# 297/297 [==============================] - 0s 487us/step - loss: 0.4920 - mean_squared_error: 0.4920 - val_loss: 0.2489 - val_mean_squared_error: 0.2489
#
# Epoch 00499: val_loss did not improve from 55.98467
# Epoch 500/500
# 297/297 [==============================] - 0s 457us/step - loss: 0.5902 - mean_squared_error: 0.5902 - val_loss: 0.2478 - val_mean_squared_error: 0.2478
#
# Epoch 00500: val_loss did not improve from 55.98467
#  save weight
# 計算 error
# Train Score: 0.11506 MSE (0.34 RMSE)
# Test Score: 0.24785 MSE (0.50 RMSE)
#
#  Predicted Stock Prices
# [[9.04289  ]
#  [9.061871 ]
#  [9.001932 ]
#  [8.899211 ]
#  [8.743395 ]
#  [8.679093 ]
#  [8.651971 ]
#  [8.601701 ]
#  [8.642204 ]
#  [8.594291 ]
#  [8.767999 ]
#  [8.616202 ]
#  [8.404811 ]
#  [8.063648 ]
#  [7.917576 ]
#  [7.8435764]
#  [7.8409424]
#  [7.7795515]
#  [7.6855793]
#  [7.4436073]
#  [7.1595573]
#  [6.7794514]
#  [6.511174 ]
#  [6.310751 ]
#  [6.1999083]
#  [6.1453056]
#  [6.1349983]
#  [6.0868025]
#  [6.0717545]
#  [6.1199856]
#  [6.1374006]
#  [6.1730967]]
#
#  Actual Stock Prices
# [[9.42]
#  [9.18]
#  [9.  ]
#  [8.9 ]
#  [8.97]
#  [9.01]
#  [8.82]
#  [9.07]
#  [8.71]
#  [8.53]
#  [8.21]
#  [7.91]
#  [8.01]
#  [8.02]
#  [8.14]
#  [7.98]
#  [7.85]
#  [7.56]
#  [7.44]
#  [7.09]
#  [6.3 ]
#  [6.45]
#  [6.04]
#  [5.91]
#  [5.52]
#  [5.57]
#  [5.09]
#  [5.09]
#  [5.44]
#  [5.4 ]
#  [5.59]
#  [5.3 ]]
# 畫圖
#
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
